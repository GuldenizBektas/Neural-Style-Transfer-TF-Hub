# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow_hub as hub
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
# preprocess image and load

def load_image(img_path):
  img = tf.io.read_file(img_path)
  img = tf.image.decode_image(img, channels = 3)
  img = tf.image.convert_image_dtype(img, tf.float32)
  img = img[tf.newaxis, :]
  return img

# %%
content_image = load_image("/content/drive/MyDrive/Colab/Images/istanbul.jpg")
style_image = load_image("/content/drive/MyDrive/Colab/Images/vangogh.jpg")

# %%
content_image.shape
# Out:
# TensorShape([1, 672, 1007, 3])

# %%
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
stylize_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(stylize_image))
plt.show()

# %%
cv2.imwrite("/content/drive/MyDrive/Colab/Images/generated_image.jpg", cv2.cvtColor(np.squeeze(stylize_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image2 = load_image("/content/drive/MyDrive/Colab/Images/tokyo.jpg")
style_image2 = load_image("/content/drive/MyDrive/Colab/Images/vangogh.jpg")

# %%
stylized_image2 = model(tf.constant(content_image2), tf.constant(style_image2))[0]

# %%
plt.imshow(np.squeeze(stylized_image2))
plt.show()

# %%
cv2.imwrite("/content/drive/MyDrive/Colab/Images/generated_image2.jpg", cv2.cvtColor(np.squeeze(stylized_image2)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image2 = load_image("/content/drive/MyDrive/Colab/Images/istanbul.jpg")
style_image2 = load_image("/content/drive/MyDrive/Colab/Images/scream.jpg")

# %%
content_image.shape
# Out:
# TensorShape([1, 672, 1007, 3])

# %%
stylized_image3 = model(tf.constant(content_image2), tf.constant(style_image2))[0]

# %%
plt.imshow(np.squeeze(stylized_image3))
plt.show()

# %%
cv2.imwrite("/content/drive/MyDrive/Colab/Images/generated_image3.jpg", cv2.cvtColor(np.squeeze(stylized_image3)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image3 = load_image("/content/drive/MyDrive/Colab/Images/ben.jpg")
style_image3 = load_image("/content/drive/MyDrive/Colab/Images/scream.jpg")

# %%
stylized_image4 = model(tf.constant(content_image3), tf.constant(style_image3))[0]

# %%
plt.imshow(np.squeeze(stylized_image4))
plt.show()

# %%
cv2.imwrite("/content/drive/MyDrive/Colab/Images/generated_image4.jpg", cv2.cvtColor(np.squeeze(stylized_image4)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image4 = load_image("/content/drive/MyDrive/Colab/Images/ben_barnes.jpg")
style_image4 = load_image("/content/drive/MyDrive/Colab/Images/vangogh2.jpg")

# %%
content_image.shape
# Out:
# TensorShape([1, 672, 1007, 3])

# %%
generate_image5 = model(tf.constant(content_image4), tf.constant(style_image4))[0]

# %%
plt.imshow(np.squeeze(generate_image5))
plt.show()

# %%
cv2.imwrite("/content/drive/MyDrive/Colab/Images/generated_image5.jpg", cv2.cvtColor(np.squeeze(generate_image5)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
def generate(content, style, number):
  content_image = load_image(content)
  style_image = load_image(style)

  stylized = model(tf.constant(content_image), tf.constant(style_image))[0]

  plt.imshow(np.squeeze(stylized))
  plt.show()

  cv2.imwrite("/content/drive/MyDrive/Colab/Images/generated_image{}.jpg".format(number), cv2.cvtColor(np.squeeze(stylized)*255, cv2.COLOR_BGR2RGB))

# %%
generate("/content/drive/MyDrive/Colab/Images/henry_cavill.jpg", "/content/drive/MyDrive/Colab/Images/scream.jpg", 7)

# %%
generate("/content/drive/MyDrive/Colab/Images/london-house-hotel.jpg", "/content/drive/MyDrive/Colab/Images/vangogh2.jpg", 8)

# %%
generate("/content/drive/MyDrive/Colab/Images/tokyo2.jpg", "/content/drive/MyDrive/Colab/Images/vangogh2.jpg", 9)

# %%
generate("/content/drive/MyDrive/Colab/Images/london-eye.jpg", "/content/drive/MyDrive/Colab/Images/vangogh2.jpg", 10)

# %%
generate("/content/drive/MyDrive/Colab/Images/istanbul.jpg", "/content/drive/MyDrive/Colab/Images/vangogh2.jpg", 11)

# %%
generate("/content/drive/MyDrive/Colab/Images/dean_winchester.jpg", "/content/drive/MyDrive/Colab/Images/vangogh.jpg", 12)

# %%
generate("/content/drive/MyDrive/Colab/Images/dean_winchester.jpg", "/content/drive/MyDrive/Colab/Images/scream.jpg", 13)

# %%
generate("/content/drive/MyDrive/Colab/Images/dean_winchester2.jpg", "/content/drive/MyDrive/Colab/Images/vangogh.jpg", 14)
